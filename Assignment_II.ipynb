# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
#Loading DATASET
df = sns.load_dataset("car_crashes")

# %%
df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %%
df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
d1 = df[["abbrev",'total','speeding','alcohol','not_distracted','no_previous','ins_premium','ins_losses']].sort_values(by="ins_premium").tail(10)
d2 = df[["abbrev",'total','speeding','alcohol','not_distracted','no_previous','ins_premium','ins_losses']].sort_values(by='ins_losses').tail(10)
d3 = df[["abbrev","ins_premium"]].sort_values(by="ins_premium").head(10)
d5 = df[["abbrev",'total','speeding','alcohol','not_distracted','no_previous','ins_premium','ins_losses']].sort_values(by='total').head(10)

# %%
ax = sns.scatterplot(x="ins_losses", y="ins_premium", data=df, s=40, color=".1")

# %%
#Scatter plot shown between no_previous and ins_losses

ax = sns.scatterplot(x=d2["no_previous"], y=d2["ins_losses"],hue=d2["abbrev"])

# %%
#Scatter plot shown between no_previous and ins_premium

ax = sns.scatterplot(x=d5["no_previous"], y=d5["ins_premium"],hue=d5["abbrev"])

# %%
#Scatter plot shown between ins_premium and ins_losses

ax = sns.scatterplot(x=d5["ins_premium"], y=d5["ins_losses"],hue=d5["abbrev"])

# %%
#Relplot between total and ins_premium

sns.relplot(x="total",y="ins_premium",data=d5,hue="abbrev")

# %%
#Plotting a bar plot of the top 10 states with highest car insurance premium

plt.figure(figsize=(12,10))
sns.barplot(x=d1['abbrev'], y=d1['ins_premium'],palette=sns.cubehelix_palette(len(d1['abbrev'])))
plt.xticks(rotation= 90)
plt.xlabel('ABBREV')
plt.ylabel('ins_premium')
plt.title('Costliest car_insurance_premiums top 10 states')
plt.show()

# %%
#Plotting a bar plot of the top 10 states with highest losses incurred by insurance companies

plt.figure(figsize=(12,10))
sns.barplot(x=d2['abbrev'], y=d2['ins_losses'],palette=sns.cubehelix_palette(len(d2['abbrev']),start=0.5,rot=-0.75))
plt.xticks(rotation= 90)
plt.xlabel('ABBREV')
plt.ylabel('ins_losses')
plt.title('Top 10 states with maximum ins_losses')
plt.show()

# %%
#Plotting a bar plot of the top 10 states with lowest car insurance premium

plt.figure(figsize=(12,10))
sns.barplot(x=d3['abbrev'], y=d3['ins_premium'],palette=sns.cubehelix_palette(len(d3['abbrev'])))
plt.xticks(rotation= 90)
plt.xlabel('ABBREV')
plt.ylabel('ins_premium')
plt.title('cheapest ins_premium top 10 states')
plt.show()

# %%
#Plotting a bar plot of the top 10 states with least number of drivers involved in fatal collisions

plt.figure(figsize=(12,10))
sns.barplot(x=d5['abbrev'], y=d5['total'],palette=sns.cubehelix_palette(len(d5['abbrev'])))
plt.xticks(rotation= 90)
plt.xlabel('ABBREV')
plt.ylabel('TOTAL')
plt.title('Top 10 states with least TOTAL')
plt.show()

# %%
d5["abbrev"].value_counts()
# Out:
# DC    1
# MA    1
# MN    1
# WA    1
# CT    1
# RI    1
# NJ    1
# UT    1
# NH    1
# CA    1
# Name: abbrev, dtype: int64

# %%
#Distplot of total

sns.distplot(df["total"])
# Out:
# <ipython-input-24-4f06d9ffaf33>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["total"])
# <Axes: xlabel='total', ylabel='Density'>

# %%
#Line Plot between ins_premium and total

sns.lineplot(x="ins_premium",y="total",data=d5,ci=None)
# Out:
# <ipython-input-25-d7e64f44eba0>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x="ins_premium",y="total",data=d5,ci=None)
# <Axes: xlabel='ins_premium', ylabel='total'>

# %%
#Line Plot between ins_losses and total

sns.lineplot(x="ins_losses",y="total",data=d5,ci=None)
# Out:
# <ipython-input-26-70c697c0c43f>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x="ins_losses",y="total",data=d5,ci=None)
# <Axes: xlabel='ins_losses', ylabel='total'>

# %%
#Line Plot between ins_premium and ins_losses

sns.lineplot(x="ins_losses",y="ins_premium",data=d5,ci=None)
# Out:
# <ipython-input-27-bc2bdf7fb45c>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x="ins_losses",y="ins_premium",data=d5,ci=None)
# <Axes: xlabel='ins_losses', ylabel='ins_premium'>

# %%
#Joint Plot between ins_premium and total

sns.jointplot(x="total",y="ins_premium",data=df)

# %%
#Box Plot between abbrev and total

sns.boxplot(x="abbrev",y="total",data=d5)
# Out:
# <Axes: xlabel='abbrev', ylabel='total'>

# %%
corr = df.corr()
corr
# Out:
# <ipython-input-30-4381f08f6434>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# ...

# %%
#Heatmap of corr

sns.heatmap(corr,annot=True,cmap="YlGnBu")
# Out:
# <Axes: >
